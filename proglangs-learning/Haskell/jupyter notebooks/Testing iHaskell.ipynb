-- %%
print "Test"
-- Out:
-- "Test"

-- %%
:opt no-pager

-- %%
:hoogle :: hPutStrLn
-- Out:
-- undefined :: a
-- URL: http://hackage.haskell.org/packages/archive/base/latest/doc/html/Prelude.html#v:undefined
-- A special case of error. It is expected that compilers will recognize this and insert error messages which are more appropriate to the context in which undefined appears.
-- discard :: a
-- URL: http://hackage.haskell.org/packages/archive/QuickCheck/latest/doc/html/Test-QuickCheck.html#v:discard
-- A special exception that makes QuickCheck discard the test case. Normally you should use ==>, but if for some reason this isn't possible (e.g. you are deep inside a generator), use discard instead.
-- fix :: (a -> a) -> a
-- URL: http://hackage.haskell.org/packages/archive/base/latest/doc/html/Data-Function.html#v:fix
-- fix f is the least fixed point of the function f, i.e. the least defined x such that f x = x.
-- throw :: Exception e => e -> a
-- URL: http://hackage.haskell.org/packages/archive/base/latest/doc/html/Control-Exception-Base.html#v:throw
-- ...

-- %%
import System.IO (stdout, hFlush)

-- %%
import IHaskell.Display

-- %%
:info DisplayData
-- Out:
-- data DisplayData = DisplayData IHaskell.IPython.Types.MimeType Data.Text.Internal.Text 	-- Defined in ‘IHaskell.IPython.Types’
-- instance Show DisplayData -- Defined in ‘IHaskell.IPython.Types’
-- instance IHaskellDisplay DisplayData -- Defined in ‘IHaskell.Display’
